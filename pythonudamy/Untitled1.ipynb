# %%
import pandas as pd
import glob 
import datetime as dt

# %%
#https://github.com/KeithGalli/Pandas-Data-Science-Tasks/blob/master/SalesAnalysis/SalesAnalysis.ipynb

# %%
file = [filename  for filename in glob.iglob('/home/rijin/sales/Pandas-Data-Science-Tasks/SalesAnalysis/Sales_Data/*.csv',recursive = True)]

# %%
file
# Out:
# ['/home/rijin/sales/Pandas-Data-Science-Tasks/SalesAnalysis/Sales_Data/Sales_March_2019.csv',
#  '/home/rijin/sales/Pandas-Data-Science-Tasks/SalesAnalysis/Sales_Data/Sales_September_2019.csv',
#  '/home/rijin/sales/Pandas-Data-Science-Tasks/SalesAnalysis/Sales_Data/Sales_November_2019.csv',
#  '/home/rijin/sales/Pandas-Data-Science-Tasks/SalesAnalysis/Sales_Data/Sales_May_2019.csv',
#  '/home/rijin/sales/Pandas-Data-Science-Tasks/SalesAnalysis/Sales_Data/Sales_June_2019.csv',
#  '/home/rijin/sales/Pandas-Data-Science-Tasks/SalesAnalysis/Sales_Data/Sales_October_2019.csv',
#  '/home/rijin/sales/Pandas-Data-Science-Tasks/SalesAnalysis/Sales_Data/Sales_April_2019.csv',
#  '/home/rijin/sales/Pandas-Data-Science-Tasks/SalesAnalysis/Sales_Data/Sales_December_2019.csv',
#  '/home/rijin/sales/Pandas-Data-Science-Tasks/SalesAnalysis/Sales_Data/Sales_January_2019.csv',
#  '/home/rijin/sales/Pandas-Data-Science-Tasks/SalesAnalysis/Sales_Data/Sales_July_2019.csv',
# ...

# %%
datas=[]

for i in file:
    a = pd.read_csv(i)
    #print(a)
    datas.append(a)
total_data = pd.concat(datas,ignore_index=True)

# %%
total_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        162009                      iPhone                1        700
# 1        162009    Lightning Charging Cable                1      14.95
# 2        162009            Wired Headphones                2      11.99
# 3        162010  Bose SoundSport Headphones                1      99.99
# 4        162011      34in Ultrawide Monitor                1     379.99
# ...         ...                         ...              ...        ...
# 186845   248146  Bose SoundSport Headphones                1      99.99
# 186846   248147      AAA Batteries (4-pack)                3       2.99
# 186847   248148       AA Batteries (4-pack)                1       3.84
# 186848   248149        USB-C Charging Cable                1      11.95
# 186849   248150       AA Batteries (4-pack)                1       3.84
#
#             Order Date                         Purchase Address
# ...

# %%
total_data.head(10)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   162009                      iPhone                1        700
# 1   162009    Lightning Charging Cable                1      14.95
# 2   162009            Wired Headphones                2      11.99
# 3   162010  Bose SoundSport Headphones                1      99.99
# 4   162011      34in Ultrawide Monitor                1     379.99
# 5   162012       AA Batteries (4-pack)                1       3.84
# 6   162013      34in Ultrawide Monitor                1     379.99
# 7   162014        USB-C Charging Cable                1      11.95
# 8   162015       AA Batteries (4-pack)                1       3.84
# 9   162016      AAA Batteries (4-pack)                5       2.99
#
#        Order Date                       Purchase Address
# 0  03/28/19 20:59        942 Church St, Austin, TX 73301
# 1  03/28/19 20:59        942 Church St, Austin, TX 73301
# 2  03/28/19 20:59        942 Church St, Austin, TX 73301
# ...

# %%
total_data.to_csv('fulldata.csv',index=False)

# %%
alldata = pd.read_csv('fulldata.csv')
alldata.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   162009                      iPhone                1        700
# 1   162009    Lightning Charging Cable                1      14.95
# 2   162009            Wired Headphones                2      11.99
# 3   162010  Bose SoundSport Headphones                1      99.99
# 4   162011      34in Ultrawide Monitor                1     379.99
#
#        Order Date                      Purchase Address
# 0  03/28/19 20:59       942 Church St, Austin, TX 73301
# 1  03/28/19 20:59       942 Church St, Austin, TX 73301
# 2  03/28/19 20:59       942 Church St, Austin, TX 73301
# 3  03/17/19 05:39  261 10th St, San Francisco, CA 94016
# 4  03/10/19 00:01  764 13th St, San Francisco, CA 94016

# %%
alldata['Order Date']
# Out:
# 0         03/28/19 20:59
# 1         03/28/19 20:59
# 2         03/28/19 20:59
# 3         03/17/19 05:39
# 4         03/10/19 00:01
#                ...
# 186845    08/29/19 22:19
# 186846    08/31/19 16:26
# 186847    08/02/19 07:25
# 186848    08/08/19 12:10
# 186849    08/16/19 08:13
# Name: Order Date, Length: 186850, dtype: object

# %%
nan_data = alldata[alldata.isna().any(axis=1)]

# %%
alldata = alldata.dropna(how = 'all')

# %%
alldata.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   162009                      iPhone                1        700
# 1   162009    Lightning Charging Cable                1      14.95
# 2   162009            Wired Headphones                2      11.99
# 3   162010  Bose SoundSport Headphones                1      99.99
# 4   162011      34in Ultrawide Monitor                1     379.99
#
#        Order Date                      Purchase Address
# 0  03/28/19 20:59       942 Church St, Austin, TX 73301
# 1  03/28/19 20:59       942 Church St, Austin, TX 73301
# 2  03/28/19 20:59       942 Church St, Austin, TX 73301
# 3  03/17/19 05:39  261 10th St, San Francisco, CA 94016
# 4  03/10/19 00:01  764 13th St, San Francisco, CA 94016

# %%
#alldata = alldata[alldata['Order Date'].str[0:2] != 'or']
alldata = alldata[alldata['Order Date'].str[0:2]!='Or']

# %%
alldata['month'] = alldata['Order Date'].str[0:2]
alldata['month'] = alldata['month'].astype('int32')
alldata.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   162009                      iPhone                1        700
# 1   162009    Lightning Charging Cable                1      14.95
# 2   162009            Wired Headphones                2      11.99
# 3   162010  Bose SoundSport Headphones                1      99.99
# 4   162011      34in Ultrawide Monitor                1     379.99
#
#        Order Date                      Purchase Address  month
# 0  03/28/19 20:59       942 Church St, Austin, TX 73301      3
# 1  03/28/19 20:59       942 Church St, Austin, TX 73301      3
# 2  03/28/19 20:59       942 Church St, Austin, TX 73301      3
# 3  03/17/19 05:39  261 10th St, San Francisco, CA 94016      3
# 4  03/10/19 00:01  764 13th St, San Francisco, CA 94016      3

# %% [markdown]
# # convert data to numeric

# %%
alldata['Quantity Ordered'] = pd.to_numeric(alldata['Quantity Ordered'])
alldata['Price Each'] = pd.to_numeric(alldata['Price Each'])

# %%
alldata.groupby(['month']).sum()
# Out:
#        Quantity Ordered    Price Each
# month
# 1                 10903  1.811768e+06
# 2                 13449  2.188885e+06
# 3                 17005  2.791208e+06
# 4                 20558  3.367671e+06
# 5                 18667  3.135125e+06
# 6                 15253  2.562026e+06
# 7                 16072  2.632540e+06
# 8                 13448  2.230345e+06
# 9                 13109  2.084992e+06
# 10                22703  3.715555e+06
# 11                19798  3.180601e+06
# 12                28114  4.588415e+06

# %%
alldata['Sales'] = alldata['Quantity Ordered'].astype('int') * alldata['Price Each'].astype('float')

# %%
import matplotlib.pyplot as plt

months = range(1,13)
print(months)

plt.bar(months,alldata.groupby(['month']).mean()['Sales'])
plt.xticks(months)
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month number')
plt.show()
# Out:
# range(1, 13)
